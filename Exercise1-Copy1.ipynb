# %% [markdown]
# # Lesson 1: Exercise 1
#
# ## Creating Data and Backtesting a Trading Strategy
#
# ---
#
# ## Overview
#
# Welcome to this Exercise. We are now going to put our skills to the test and create a dataset and prepare our first backtests. Proper data preparation is essential to conducting succesful backtest, and we want to make sure that we build a solid foundation and develop proper techniques to ensure that we can build our datasets easily at scale and develop proper data wrangling and preparation approaches. In particular, we are going to cover the  essential steps that are necessary to succesfully build trading  models beginning from creating datasets from publicly available stock price data to conducting exploratory data analysis to finally building and testing models. We are then quickly shifts gears and illustrate a few advanced investment ideas that can be used for further analysis.

# %%
import sys
import os

# Manually set the path relative to the py file's location that you want to import
func_lib_path = os.path.abspath(os.path.join(os.getcwd(), '../../'))
# Add the path to sys.path
sys.path.append(func_lib_path)
# Now you can import func_lib
import func_lib

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Calculate accuracy, precision, and recall
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
#  Create a variable named 'historical_prices' to store historical price data between the dates'2005-01-01' and '2015-01-01'. Use the function 'create_hist_prices()' from 'func_lib' to generate or retrieve the historical prices.
historical_prices = func_lib.create_hist_prices(start_date = '2005-01-01', end_date = '2015-01-01')
# Create a list named 'list_of_momentums' and add 1 to the list
list_of_momentums = [1]
# Compute the total returns using the historical prices and the list of momentums. Use the 'compute_returns()' function from 'func_lib'. Pass 'historical_prices' and 'list_of_momentums' as arguments to 'func_lib.compute_returns()'.
# - Store the result in a variable named 'total_returns'.
total_returns     = func_lib.compute_returns(historical_prices, list_of_momentums)
# Use the 'dropna()' method on the 'total_returns' DataFrame.
total_returns.dropna(inplace=True)
# Out:
# Failed to get ticker 'GOOGL' reason: Expecting value: line 1 column 1 (char 0)
# [                       0%                       ]Failed to get ticker 'CL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GEN' reason: Expecting value: line 1 column 1 (char 0)
# [                       0%                       ]  2 of 501 completedFailed to get ticker 'AWK' reason: Expecting value: line 1 column 1 (char 0)
# [                       1%                       ]  3 of 501 completedFailed to get ticker 'GILD' reason: Expecting value: line 1 column 1 (char 0)
# [                       1%                       ]  4 of 501 completedFailed to get ticker 'MCD' reason: Expecting value: line 1 column 1 (char 0)
# [                       1%                       ]  4 of 501 completedFailed to get ticker 'MOH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'TMUS' reason: Expecting value: line 1 column 1 (char 0)
# [                       1%                       ]  6 of 501 completedFailed to get ticker 'XOM' reason: Expecting value: line 1 column 1 (char 0)
# [*                      2%                       ]  8 of 501 completedFailed to get ticker 'GIS' reason: Expecting value: line 1 column 1 (char 0)
# [*                      2%                       ]  9 of 501 completedFailed to get ticker 'NTAP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'COR' reason: Expecting value: line 1 column 1 (char 0)
# [*                      2%                       ]  10 of 501 completedFailed to get ticker 'CINF' reason: Expecting value: line 1 column 1 (char 0)
# [*                      2%                       ]  10 of 501 completedFailed to get ticker 'MPWR' reason: Expecting value: line 1 column 1 (char 0)
# [*                      2%                       ]  12 of 501 completedFailed to get ticker 'VRSK' reason: Expecting value: line 1 column 1 (char 0)
# [*                      3%                       ]  13 of 501 completedFailed to get ticker 'TROW' reason: Expecting value: line 1 column 1 (char 0)
# [*                      3%                       ]  15 of 501 completedFailed to get ticker 'SRE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BX' reason: Expecting value: line 1 column 1 (char 0)
# [*                      3%                       ]  16 of 501 completedFailed to get ticker 'HII' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BR' reason: Expecting value: line 1 column 1 (char 0)
# [**                     4%                       ]  19 of 501 completedFailed to get ticker 'XEL' reason: Expecting value: line 1 column 1 (char 0)
# [**                     4%                       ]  20 of 501 completedFailed to get ticker 'HCA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'TSCO' reason: Expecting value: line 1 column 1 (char 0)
# [**                     4%                       ]  21 of 501 completedFailed to get ticker 'WFC' reason: Expecting value: line 1 column 1 (char 0)
# [**                     4%                       ]  22 of 501 completedFailed to get ticker 'TRMB' reason: Expecting value: line 1 column 1 (char 0)
# [**                     4%                       ]  22 of 501 completedFailed to get ticker 'NDSN' reason: Expecting value: line 1 column 1 (char 0)
# [**                     5%                       ]  24 of 501 completedFailed to get ticker 'EQIX' reason: Expecting value: line 1 column 1 (char 0)
# [**                     5%                       ]  25 of 501 completedFailed to get ticker 'KHC' reason: Expecting value: line 1 column 1 (char 0)
# [**                     5%                       ]  26 of 501 completedFailed to get ticker 'CSCO' reason: Expecting value: line 1 column 1 (char 0)
# [***                    6%                       ]  28 of 501 completedFailed to get ticker 'VST' reason: Expecting value: line 1 column 1 (char 0)
# [***                    6%                       ]  29 of 501 completedFailed to get ticker 'ROL' reason: Expecting value: line 1 column 1 (char 0)
# [***                    6%                       ]  30 of 501 completedFailed to get ticker 'LYB' reason: Expecting value: line 1 column 1 (char 0)
# [***                    6%                       ]  31 of 501 completedFailed to get ticker 'CI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PRU' reason: Expecting value: line 1 column 1 (char 0)
# [***                    7%                       ]  33 of 501 completedFailed to get ticker 'FTV' reason: Expecting value: line 1 column 1 (char 0)
# [***                    7%                       ]  34 of 501 completedFailed to get ticker 'ERIE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MAS' reason: Expecting value: line 1 column 1 (char 0)
# [***                    7%                       ]  36 of 501 completedFailed to get ticker 'HON' reason: Expecting value: line 1 column 1 (char 0)
# [***                    7%                       ]  36 of 501 completedFailed to get ticker 'DLR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'TMO' reason: Expecting value: line 1 column 1 (char 0)
# [****                   8%                       ]  38 of 501 completedFailed to get ticker 'FFIV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JBHT' reason: Expecting value: line 1 column 1 (char 0)
# [****                   8%                       ]  40 of 501 completedFailed to get ticker 'FE' reason: Expecting value: line 1 column 1 (char 0)
# [****                   8%                       ]  42 of 501 completedFailed to get ticker 'J' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RF' reason: Expecting value: line 1 column 1 (char 0)
# [****                   9%                       ]  44 of 501 completedFailed to get ticker 'OKE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RVTY' reason: Expecting value: line 1 column 1 (char 0)
# [****                   9%                       ]  46 of 501 completedFailed to get ticker 'GOOG' reason: Expecting value: line 1 column 1 (char 0)
# [****                   9%                       ]  47 of 501 completedFailed to get ticker 'DPZ' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 10%                       ]  48 of 501 completedFailed to get ticker 'ADBE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'SNPS' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 10%                       ]  50 of 501 completedFailed to get ticker 'MO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CPB' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 10%                       ]  50 of 501 completedFailed to get ticker 'SO' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 10%                       ]  52 of 501 completedFailed to get ticker 'ES' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 11%                       ]  54 of 501 completedFailed to get ticker 'AON' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 11%                       ]  54 of 501 completedFailed to get ticker 'PCG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CDW' reason: Expecting value: line 1 column 1 (char 0)
# [*****                 11%                       ]  56 of 501 completedFailed to get ticker 'PGR' reason: Expecting value: line 1 column 1 (char 0)
# [******                12%                       ]  58 of 501 completedFailed to get ticker 'FICO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMT' reason: Expecting value: line 1 column 1 (char 0)
# [******                12%                       ]  60 of 501 completed

# %%
# Print the first 5 lines of total returns
total_returns.head()

# %%
# Compute cumulative and calendar returns from the total returns data. 
# Use the 'compute_BM_Perf()' function from 'func_lib' to perform this calculation. 
# Pass 'total_returns' as an argument to 'func_lib.compute_BM_Perf()'.
# - The function returns two outputs: 'cum_returns' for cumulative returns and 'calendar_returns' for calendar returns.
# - Assign the outputs to the variables 'cum_returns' and 'calendar_returns' respectively.
cum_returns, calendar_returns  = func_lib.compute_BM_Perf(total_returns)

# %%
# Calculate the Relative Strength Index (RSI) for each 'Ticker' and add it to the 'total_returns' DataFrame.First, group the 'total_returns' DataFrame by the 'Ticker' column.
# For each group, select the '1_d_returns' column and apply a transformation using the 'calculate_rsi' function from 'func_lib'.
# - Assign the result to a new column named 'RSI' in the 'total_returns' DataFrame.
total_returns['RSI'] = total_returns.groupby('Ticker')[['1_d_returns']].transform(func_lib.calculate_rsi)

# %%
# Print out the first 5 rows of the total_returns dataframe
total_returns.head()
# Out:
#                                   F_1_d_returns  1_d_returns  RSI
# Ticker Date
# A      2005-01-04 00:00:00+00:00      -0.000430    -0.026382  NaN
#        2005-01-05 00:00:00+00:00      -0.021945    -0.000430  NaN
#        2005-01-06 00:00:00+00:00      -0.000880    -0.021945  NaN
#        2005-01-07 00:00:00+00:00      -0.004844    -0.000880  NaN
#        2005-01-10 00:00:00+00:00      -0.017257    -0.004844  NaN

# %%
#  Define a trading strategy function based on the RSI (Relative Strength Index). Create a function named 'trading_strategy' that accepts one parameter: 'rsi'.
# Inside the function, use an if-else statement to implement the trading logic:
#     - If 'rsi' is less than 65, return 1 (indicating a decision to go long).
#     - Otherwise, return 0 (indicating no position or a different strategy).
# - This function will be used later to determine trading actions based on RSI values.

def trading_strategy(rsi):
    if rsi < 65:
        return  1 # Go long
    else:
        return 0

# %%
# Create a variable named 'model_name' and set it to the string "RSI".
model_name = "RSI"

# %%
# Compute cumulative and calendar returns for the given trading strategy.
# Use the 'compute_strat_perf()' function from 'func_lib' to perform this calculation.
# Pass 'total_returns', 'cum_returns', 'calendar_returns', 'trading_strategy', and 'model_name' as arguments.
# - The function returns updated 'cum_returns' and 'calendar_returns' based on the strategy's performance.
cum_returns, calendar_returns  = func_lib.compute_strat_perf(total_returns, cum_returns, calendar_returns, trading_strategy, model_name)
# Out:
# The CAGR is: 15.89%
# Sharpe Ratio of Strategy: 0.78

# %%
# Create the true values (y_test) indicating whether future 1-day returns (F_1_d_returns) are larger or smaller than 0.
# Use the 'np.where()' function to evaluate the 'F_1_d_returns' column in the 'total_returns' DataFrame.
# Store the result in a new column called 'y_test' in the 'total_returns' DataFrame.
total_returns['y_test'] = np.where(total_returns['F_1_d_returns']>0,1,0)
# Copy the values from the 'Position' column of 'total_returns' to a new column named 'y_pred'.
total_returns['y_pred'] = total_returns['Position']

# %%
# Convert the 'y_test' column from the 'total_returns' DataFrame to a list using the 'tolist()' method.
# Store the result in a variable named 'y_test'.
# Similarly, convert the 'y_pred' column to a list and store it in a variable named 'y_pred'.
y_test = total_returns['y_test'].tolist()
y_pred = total_returns['y_pred'].tolist()

# %%
# Calculate the accuracy, precision, and recall of the trading strategy.
# - Use the 'accuracy_score()' function to calculate the accuracy of the predictions.
#     - Pass the actual values (y_test) and the predicted values (y_pred) as arguments.
#     - Store the result in a variable named 'accuracy'.
# - Use the 'precision_score()' function to calculate the precision of the predictions.
#     - Similarly, pass 'y_test' and 'y_pred' as arguments.
#     - Store the result in a variable named 'precision'.
# - Use the 'recall_score()' function to calculate the recall of the predictions.
#     - Again, pass 'y_test' and 'y_pred' as arguments.
#     - Store the result in a variable named 'recall'.
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
# Create a DataFrame named 'metrics_df' using the 'pd.DataFrame()' function.
# Define a dictionary with two keys: 'Metric' and 'Value'.
#     - The 'Metric' key should have a list of strings: ['Accuracy', 'Precision', 'Recall'].
#     - The 'Value' key should have a list of the calculated metrics: [accuracy, precision, recall].
metrics_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall'],
    'Value': [accuracy, precision, recall]
})

# %%
# Display the 'metrics_df' DataFrame to see the performance of the trading strategy.
metrics_df
# Out:
#       Metric     Value
# 0   Accuracy  0.511735
# 1  Precision  0.512622
# 2     Recall  0.936336
